# %%
#TODO: 3D Plot, Kugel oder Punkt durch den im 3D fahren zu lassen, Vorgeben im welchen Millimeterbereich (also Tank-Hit box und dadrin Helix fahren)

# %%
import numpy as np
import matplotlib.pyplot as plt

from src.util import plot_sphere

# %%
#Parameter des Tanks festlegen (in mm):

tank_r = 75
tank_h = 140

#Parameter der Kugel festlegen (in mm):

sphere_r = 20

# %%
pos = plot_sphere(sphere_r, tank_r, tank_h)

#TODO: Weitere 3D Trajektorien implementieren und traj als Übergabeparameter einbauen 

#TODO: mit den ausgegeben Positionen einen Voxelplot erstellen. Es reicht erstmal einen zu erstellen bzw. auf einer zufälligen Position einen Voxel-Kreis zu plotten, um es zu testen

# %%
def voxel_ball(x0, y0, z0, d=3, mask=False, indices_res=(32, 32, 32)):
    x, y, z = np.indices(indices_res)
    voxel = np.sqrt((x - x0) ** 2 + (y - y0) ** 2 + (z - z0) ** 2) < d
    if mask:
        return voxel
    else:
        return substitute_true_false(voxel)

voxel_ball(0,0,0)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 9
#       6     else:
#       7         return substitute_true_false(voxel)
# ----> 9 voxel_ball(0,0,0)
#
# Cell In[4], line 7, in voxel_ball(x0, y0, z0, d, mask, indices_res)
#       5     return voxel
#       6 else:
# ----> 7     return substitute_true_false(voxel)
#
# NameError: name 'substitute_true_false' is not defined
